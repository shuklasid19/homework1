# %% [markdown]
# 1. Where you have used Hypothesis Testing in your Machine learning Solution.
#
# We can use hypothesis testing in ml to find the diff

# %% [markdown]
# 11. What do you understand by right skewness, Give example?
# Right skewness i

# %% [markdown]
# 24. What do you understand by variance in data in simple words?
# variance of data can be explained as the spread , how much data is spreaded in the space . it tells whats how much area does the data covers, max and min of the data.range of the data over space , how much variance in space is explained by the data. its basically points in space spread within a range.
# as variance of the data increases the probability distribution function also becomes flatter.
